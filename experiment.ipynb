# %%
import wave
import os
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
load_dotenv()
# Out:
# True

# %%
groq_api_key = os.getenv('GROQ_API_KEY')

# %%
llm = ChatGroq(
    model="llama-3.1-70b-versatile",
    temperature=0.5,
    api_key=groq_api_key
)

# %%
import soundfile
import wave

file_path = "F:/Langffee/resources/A1_A_good_nights_sleep.mp3"

# Read and rewrite the file with soundfile
data, samplerate = soundfile.read(file_path)
soundfile.write(file_path, data, samplerate)

# %%
with wave.open(file_path) as file:
    print('File opened!')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 with wave.open(file_path) as file:
#       2     print('File opened!')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\wave.py:661, in open(f, mode)
#     659         mode = 'rb'
#     660 if mode in ('r', 'rb'):
# --> 661     return Wave_read(f)
#     662 elif mode in ('w', 'wb'):
#     663     return Wave_write(f)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\wave.py:286, in Wave_read.__init__(self, f)
#     284 # else, assume it is an open file object already
#     285 try:
# --> 286     self.initfp(f)
#     287 except:
#     288     if self._i_opened_the_file:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\wave.py:253, in Wave_read.initfp(self, file)
#     251 self._file = _Chunk(file, bigendian = 0)
#     252 if self._file.getname() != b'RIFF':
# --> 253     raise Error('file does not start with RIFF id')
#     254 if self._file.read(4) != b'WAVE':
#     255     raise Error('not a WAVE file')
#
# Error: file does not start with RIFF id

# %%
def listening_test():
    """Create a listening test for given audio. The test consists of 10 questions and all from the audio"""
    audio = wave.open('F:/Langffee/resources/A1_A_good_nights_sleep.mp3', 'r')
    prompt = """From the {audio} create a list of 10 mcqs. These MCQs must cover all levels of english, from A1 to C2. The questions asked must be strictly from the given audio"""
    result = llm.invoke(prompt)
    return result.content

# %%
result = listening_test()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 result = listening_test()
#
# Cell In[20], line 3, in listening_test()
#       1 def listening_test():
#       2     """Create a listening test for given audio. The test consists of 10 questions and all from the audio"""
# ----> 3     audio = wave.open('F:/Langffee/resources/A1_A_good_nights_sleep.mp3', 'r')
#       4     prompt = """From the {audio} create a list of 10 mcqs. These MCQs must cover all levels of english, from A1 to C2. The questions asked must be strictly from the given audio"""
#       5     result = llm.invoke(prompt)
#       6     return result.content
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\wave.py:661, in open(f, mode)
#     659         mode = 'rb'
#     660 if mode in ('r', 'rb'):
# --> 661     return Wave_read(f)
#     662 elif mode in ('w', 'wb'):
#     663     return Wave_write(f)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\wave.py:286, in Wave_read.__init__(self, f)
#     284 # else, assume it is an open file object already
#     285 try:
# --> 286     self.initfp(f)
#     287 except:
#     288     if self._i_opened_the_file:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\wave.py:253, in Wave_read.initfp(self, file)
#     251 self._file = _Chunk(file, bigendian = 0)
#     252 if self._file.getname() != b'RIFF':
# --> 253     raise Error('file does not start with RIFF id')
#     254 if self._file.read(4) != b'WAVE':
#     255     raise Error('not a WAVE file')
#
# Error: file does not start with RIFF id

# %%
result
# Out:
# <function __main__.listening_test()>

# %%
def reading_test():
    pass

# %%
def speaking_test():
    pass

# %%
def writing_test():
    pass

# %%
def get_to_know():
    answers = {}
    print("Why learn?\n A. For fun\n B. Career\n C. Higher studies\n D. Travel\n E. Others")
    choice = input()
    why = ""
    if choice == "A":
        why="For fun"
    elif choice=="B":
        why="Career"
    elif choice=="C":
        why="Higher studies"
    elif choice=="D":
        why="Travel"
    else:
        others = input("Explain why you want to learn english")
        why=others
    answers["Why"]=why
    return answers

# %%
get_to_know()
# Out:
# Why learn?
#  A. For fun
#  B. Career
#  C. Higher studies
#  D. Travel
#  E. Others
# {'Why': 'i want to learn english to have a conversation with my friend'}

# %%
def test():
    listening_test_results = listening_test()
    reading_test_results = reading_test()
    speaking_test_results = speaking_test()
    writing_test_results = writing_test()

# %%
def prepare_report():
    pass

# %%
def prepare_plan():
    pass

# %%
def user_decision():
    pass

# %%
def get_feedback():
    pass

# %%
def main():
    answers = get_to_know()
    test_results = test()
    report = prepare_report(test_results)
    plan = prepare_plan(report, test_results)
    decision = user_decision(plan)
    while decision != "approved":
        feedback = get_feedback()
        plan = prepare_plan(feedback)

    print(f"Proceed with {plan}")
